# %% [markdown]
# <a href="https://colab.research.google.com/github/harshchaudhary11/Machine-Learning/blob/main/Online%20Payment%20Fraud%20Detection%20using%20Machine%20Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("/content/new_file.csv")
data
# Out:
#         step      type      amount     nameOrig  oldbalanceOrg  \
# 0          1   PAYMENT     9839.64  C1231006815       170136.0
# 1          1   PAYMENT     1864.28  C1666544295        21249.0
# 2          1  TRANSFER      181.00  C1305486145          181.0
# 3          1  CASH_OUT      181.00   C840083671          181.0
# 4          1   PAYMENT    11668.14  C2048537720        41554.0
# ...      ...       ...         ...          ...            ...
# 518859    20  CASH_OUT   120450.01   C569718590            0.0
# 518860    20  CASH_OUT   162062.55   C205215512        30711.0
# 518861    20  TRANSFER   388146.68   C767875101            0.0
# 518862    20  TRANSFER    38912.00  C1175611072            0.0
# 518863    20  TRANSFER  2733209.37       C13143            NaN
#
#         newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud
# 0            160296.36  M1979787155            0.00            0.00      0.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 518864 entries, 0 to 518863
# Data columns (total 10 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   step            518864 non-null  int64
#  1   type            518864 non-null  object
#  2   amount          518864 non-null  float64
#  3   nameOrig        518864 non-null  object
#  4   oldbalanceOrg   518863 non-null  float64
#  5   newbalanceOrig  518863 non-null  float64
#  6   nameDest        518863 non-null  object
#  7   oldbalanceDest  518863 non-null  float64
#  8   newbalanceDest  518863 non-null  float64
#  9   isFraud         518863 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 39.6+ MB

# %%
data.describe()
# Out:
#                 step        amount  oldbalanceOrg  newbalanceOrig  \
# count  518864.000000  5.188640e+05   5.188630e+05    5.188630e+05
# mean       14.128257  1.650395e+05   9.066486e+05    9.264075e+05
# std         3.836852  2.706147e+05   3.003441e+06    3.040504e+06
# min         1.000000  1.000000e-01   0.000000e+00    0.000000e+00
# 25%        11.000000  1.320161e+04   0.000000e+00    0.000000e+00
# 50%        14.000000  8.055062e+04   1.853300e+04    0.000000e+00
# 75%        17.000000  2.205802e+05   1.675800e+05    2.072277e+05
# max        20.000000  1.000000e+07   3.893942e+07    3.894623e+07
#
#        oldbalanceDest  newbalanceDest        isFraud
# count    5.188630e+05    5.188630e+05  518863.000000
# mean     9.823148e+05    1.158885e+06       0.000449
# std      2.334174e+06    2.504786e+06       0.021186
# min      0.000000e+00    0.000000e+00       0.000000
# 25%      0.000000e+00    0.000000e+00       0.000000
# ...

# %%
obj = (data.dtypes == 'object')
object_cols = list(obj[obj].index)
print("Categorical variables:", len(object_cols))

int_ = (data.dtypes == 'int')
num_cols = list(int_[int_].index)
print("Integer variables:", len(num_cols))

fl = (data.dtypes == 'float')
fl_cols = list(fl[fl].index)
print("Float variables:", len(fl_cols))
# Out:
# Categorical variables: 3
# Integer variables: 1
# Float variables: 6

# %%
sns.countplot(x='type', data=data)
# Out:
# <Axes: xlabel='type', ylabel='count'>

# %%
sns.barplot(x='type', y='amount', data=data)
# Out:
# <Axes: xlabel='type', ylabel='amount'>

# %%
data['isFraud'].value_counts()
# Out:
# isFraud
# 0.0    518630
# 1.0       233
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15, 6))
sns.distplot(data['step'], bins=50)
# Out:
# /tmp/ipykernel_11742/1113131929.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['step'], bins=50)
# <Axes: xlabel='step', ylabel='Density'>

# %%
plt.figure(figsize=(12, 6))
sns.heatmap(data.apply(lambda x: pd.factorize(x)[0]).corr(),
			cmap='BrBG',
			fmt='.2f',
			linewidths=2,
			annot=True)
# Out:
# <Axes: >

# %%
type_new = pd.get_dummies(data['type'], drop_first=True)
data_new = pd.concat([data, type_new], axis=1)
data_new.head()
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  CASH_OUT  DEBIT  \
# 0  M1979787155             0.0             0.0      0.0     False  False
# 1  M2044282225             0.0             0.0      0.0     False  False
# 2   C553264065             0.0             0.0      1.0     False  False
# 3    C38997010         21182.0             0.0      1.0      True  False
# 4  M1230701703             0.0             0.0      0.0     False  False
#
#    PAYMENT  TRANSFER
# 0     True     False
# 1     True     False
# 2    False      True
# ...

# %%
X = data_new.drop(['isFraud', 'type', 'nameOrig', 'nameDest'], axis=1)
y = data_new['isFraud']

# %%
X.shape, y.shape
# Out:
# ((518864, 10), (518864,))

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42)

# %%
from xgboost import XGBClassifier
from sklearn.metrics import roc_auc_score as ras
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier

# %%
models = [LogisticRegression(max_iter=1000), XGBClassifier(),
          RandomForestClassifier(n_estimators=7,
                                 criterion='entropy',
                                 random_state=7)]

# Drop rows with NaN values from X_train and y_train
nan_rows_train = X_train.isna().any(axis=1)
X_train = X_train[~nan_rows_train]
y_train = y_train[~nan_rows_train]

# Drop rows with NaN values from X_test and y_test
nan_rows_test = X_test.isna().any(axis=1)
X_test = X_test[~nan_rows_test]
y_test = y_test[~nan_rows_test]

for i in range(len(models)):
    models[i].fit(X_train, y_train)
    print(f'{models[i]} : ')

    train_preds = models[i].predict_proba(X_train)[:, 1]
    print('Training Accuracy : ', ras(y_train, train_preds))

    y_preds = models[i].predict_proba(X_test)[:, 1]
    print('Validation Accuracy : ', ras(y_test, y_preds))
    print()
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression() :
# Training Accuracy :  0.9067186938754561
# Validation Accuracy :  0.9195825620457974
#
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
# ...

# %%
from sklearn.metrics import ConfusionMatrixDisplay
import matplotlib.pyplot as plt

cm = ConfusionMatrixDisplay.from_estimator(models[1], X_test, y_test)

cm.plot(cmap='Blues')

plt.show()
